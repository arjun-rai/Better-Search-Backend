# %%
from exa_py import Exa

# %%
exa = Exa("9e2f124a-b95c-4812-9f93-2c70e77f74cb")

# %%
results = exa.search_and_contents('free weight lifting excercise plans', use_autoprompt=True, num_results=10, text={'include_html_tags':True}, type='keyword')

# %%
# results_str = []
# for i in range(len(results.results)):
#     results_str.append("".join(map(str, results.results[i].highlights)))

# %%
# print(results.results[0].highlights[0])
# Out:
# If that doesn't work have a buddy kick you in the junk and you won't think about eating for a few hours. I haven't tried this method yet, but if you decide to try it make sure and it get on youtube for verification.

# %%
# results_str[0]
# Out:
# 'If that doesn\'t work have a buddy kick you in the junk and you won\'t think about eating for a few hours. I haven\'t tried this method yet, but if you decide to try it make sure and it get on youtube for verification.Sprints, hill sprints, prowler pushes, bag work, and sled pulling can be hard on the connective tissue and joints if you don\'t prepare properly. Overuse injuries from conditioning work will come very fast because of the repetitive motion of it all, and they don\'t go away very quickly even when treated properly.Cut out all coke/pops, candy, cookies, salad dressings, and desserts. Drink one gallon of water a day, minimum.However there will be times where you\'re just going to be hungry and you\'ll have to deal with that for a little while. Focus on your goals and hunker down.Focus on your goals and hunker down. If that doesn\'t work have a buddy kick you in the junk and you won\'t think about eating for a few hours.20 seconds of sledge hammering, then rest 10 seconds a
# ...

# %%
results.results[0].text
# Out:
# 'https://www.muscleandstrength.com/workout-routines\nFree Workout Plans\nNone\nNone\n<div><p>Choose a category that best suits the workout you\'re searching for. Once in the category, use the sort and filter options to find the right workout for your experience and goals.</p><p>The most downloaded workouts in our database during the past 24 hours. You can also find top/trending workouts by choosing a category (above) and scrolling to the "trending" view.</p><div>\n<div>\n<p>\nThis workout is designed to increase your muscle mass as much as possible in 10 weeks. Works each muscle group hard once per week using mostly heavy compound exercises. </p>\n<p>Advanced\nMale\n4 Days/Week\n</p>\n</div>\n<div>\n<p>\nThis 12 week women\'s specific training program is perfect for any healthy woman who is looking to transform her body through a good weight lifting program. </p>\n<p>Beginner\nFemale\n5 Days/Week\n</p>\n</div>\n<div>\n<p>\nThis is a complete 12 week program to help you get ripped. Fe
# ...

# %%
print(results.results[0].text)
# Out:
# https://www.muscleandstrength.com/workout-routines
# Free Workout Plans
# None
# None
# <div><p>Choose a category that best suits the workout you're searching for. Once in the category, use the sort and filter options to find the right workout for your experience and goals.</p><p>The most downloaded workouts in our database during the past 24 hours. You can also find top/trending workouts by choosing a category (above) and scrolling to the "trending" view.</p><div>
# <div>
# <p>
# This workout is designed to increase your muscle mass as much as possible in 10 weeks. Works each muscle group hard once per week using mostly heavy compound exercises. </p>
# <p>Advanced
# Male
# 4 Days/Week
# </p>
# </div>
# <div>
# <p>
# This 12 week women's specific training program is perfect for any healthy woman who is looking to transform her body through a good weight lifting program. </p>
# <p>Beginner
# Female
# 5 Days/Week
# </p>
# </div>
# <div>
# <p>
# ...

# %%
import instructor
from openai import OpenAI
from pydantic import BaseModel, Field, field_validator
from typing_extensions import Literal
from typing import List, Dict, Optional
import tiktoken

# %%
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
client = instructor.patch(OpenAI(api_key='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'))

# %%
class Excercise(BaseModel):
    name: str = Field(description="name of the specific exercise that is part of the plan")
    # duration: Optional[str] = Field(description="duration of the excercise")
    additional_notes: Optional[str] = Field("any additional notes or instructions for the exercise")

    # @field_validator('time')
    # def check_time(cls, value):
    #     return value
# class Day(BaseModel):
#     day: str = Field(description='which day to do these exercise on')
#     excercises: List[Excercise]

class Plan(BaseModel):
    type_plan: str = Field(description="Must be the type of the exercise plan")
    description: str = Field(description="description of the workout plan")
    duration: str = Field(description="length of workout plan")
    intensity: Literal['low', 'medium', 'high']
    equipment_required: List[str] = Field(description="equipment needed to do the workout plan")
    target_areas: List[str] = Field(description="which muscle groups or areas that the workout plan focuses on")
    difficulty: Literal['beginner','intermediate', 'advanced']
    additional_notes: str = Field("any additional notes or instructions for the workout plan")
    excercises: List[Excercise]


resp = client.chat.completions.create(
    model="gpt-3.5-turbo-0125",
    messages=[{"role": "user", "content": 'You are an athlete looking to find exercise plans, you find {}. Process the information into an easy to read workout plan.'.format(results.results[6].text)}],
    response_model=Plan,
)
resp.model_dump()
# Out:
# {'type_plan': 'Dumbbell Strength Conditioning Workout',
#  'description': 'A full-body workout plan that focuses on muscle building, strength, and conditioning using only dumbbells. The plan consists of four complexes designed to challenge different muscle groups and improve overall fitness levels. Each complex includes specific exercises to be performed in a structured sequence with rest intervals in between.',
#  'duration': '2-3 weeks',
#  'intensity': 'high',
#  'equipment_required': ['Pair of dumbbells'],
#  'target_areas': ['Full body muscles including arms, chest, back, shoulders, legs, and core'],
#  'difficulty': 'intermediate',
#  'additional_notes': 'any additional notes or instructions for the workout plan',
#  'excercises': [{'name': 'Power and Strength Complex',
#    'additional_notes': 'Consists of cleans, push-presses, and front squats. Focus on explosive movements and proper form.'},
#   {'name': 'Hypertrophy Complex',
# ...
