# %%
import json

# %%
f = open('data.json')
 
data = json.load(f)

# %%
print(data[1])
# Out:
# 6-Week High Intensity Training Program:
#
# Weeks 1-2:
#
# DAY 1:
#
# WORKOUT - 7 MINUTE AMRAP:
# - Split Lunge: 10 Each Side
# - Lying Toe Taps: 20
# - Mountain Climbers: 30 seconds
#
# MIDWORKOUT CHALLENGE:
# - Burpees: 100
# - Plank Knees to Toes: 100
#
# WORKOUT - TABATA:
# - Forward/Reverse Bear Crawls: 30 Seconds
# - Jumping Jacks: 100 Minute
# - Burpees with Strict Pushup: 30 Seconds
#
# 12 MINUTE AMRAP:
# - Air Squats: 10
# - Push Ups: 8
# - Bicycle Crunches: 30 Seconds
#
# WORKOUT - AMRAP:
# - Plank Shoulder Taps: 20
# - Side Lunge: 10 Each Side
# - Running In Place: 30 Seconds
# - Bicycles: 30 Seconds
#
# DAY 2:
#
# WORKOUT - 7 Minute AMRAP:
# - High Knees: 30 Seconds
# - Curtsy Lunges: 10 Each Side
# - Chair Triceps Dips: 12
#
# WORKOUT - EMOM 5 Rounds:
# - Overhead Front Lunges: 15
# - Plank Toe Touches: 12
# - Glute Bridges: 15
# - Jump Squats: 8
#
# WORKOUT - 3 ROUNDS FOR TIME:
# - Air Squats: 50
# - Mountain Climbers: 40
# - V Ups: 30
# - Push Ups: 20
# - Reverse Lunges: 10
# - Jumping Jacks: 100
#
# DAY 3:
#
# WORKOUT - 10 Minute AMRAP:
# - Fast Feet: 30 Seconds
# - Burpees: 8
# - Alternating Reverse Lung: 12 Each Side
#
# WORKOUT - TABATA:
# - Box Jumps: 30 Seconds
# - Bicycles: 20 Seconds
# - Butt Kickers: 20 Seconds
#
# WORKOUT - 10 Minute AMRAP:
# - Lateral Lunge: 10 Each Side
# - Skaters: 30 Seconds
# - Sit Up To Glute Bridge: 15
# - Jackknife: 10
#
# DAY 4:
#
# WORKOUT - AMRAP 6 Rounds:
# - Sumo Squats: 12
# - High Knees: 30 Seconds
# - Mountain Climbers: 45 Seconds
# - Alternating Jump Lunges: 10 Reps Each Side
#
# WORKOUT - AMRAP 4 Rounds:
# - Narrow Push Ups: 12
# - Sit Up To Glute Bridge: 10
# - Curtsy Lunges: 12 each side
#
# AB Finisher - 4 Rounds:
# - Suitcase Sit Ups: 15
# - Bicycles: 15
# - Heel Touches: 15
# - Cross Leg Reverse Crunch: 15
#
# DAY 5:
#
# WORKOUT - TABATA:
# - Pulsing Squats: 30 Seconds
# - Side Planks: 45 Seconds
# - Russian Twists: 45 Seconds
#
# WORKOUT - 5 Rounds:
# - Tricep Dips: 20
# - High Knees: 20
# - Squats: 10
# - Push Ups: 10
# - Dead Bugs: 10
#
# Weeks 3-4:
#
# DAY 1:
#
# WORKOUT - 8 Minute EMOM:
# - Squat Jacks: 20
# - High Knees: 25
#
# WORKOUT - AMRAP 8 Rounds:
# - Tricep Dips: 10
# - Jumping Lunges: 15
# - Butt Kickers: 20
# - Speed Skaters: 30
#
# DAY 2:
#
# WORKOUT - 20 Minute AMRAP:
# - Side Lunge With Hop: 10 Each Side
# - Burpees: 15
# - Jump Squats: 10
# - Push Ups: 12
#
# AB Finisher - 4 Rounds:
# - Bicycles: 1 Min
# - Mountain Climbers: 1 Min
# - Reverse Lunge: 20
#
# DAY 3:
#
# WORKOUT - TABATA:
# - Plank Jacks: 10 Seconds
# - Lying Glute Bridges: 20 Seconds
#
# WORKOUT - 10 Minute AMRAP:
# - Pendulum Lunge: 10
# - Plank T Spine Rotations: 10
# - V-Ups: 10
# - Squats With Knee Drive Twist: 10
#
# DAY 4:
#
# WORKOUT - EMOM:
# - Plie Squat Punch: 10
# - Forward/Reverse Bear Crawl: 12
# - Bicycle Abs: 30 Seconds
# - Push Ups: 12
#
# WORKOUT - 15 Minute AMRAP:
# - Jumping Jacks: 1 Min
# - Squats With Knee Raise: 20
# - High Knees: 1 Min
# - Narrow Push Ups: 20
# - V-Ups: 20
# - Fast Feet: 1 Min
#
# DAY 5:
#
# WORKOUT - 6 Rounds:
# - Squats: 30
# - Narrow Push Ups: 30
# - Pendulum Lunge: 15 Each Side
# - Glute Bridge: 20
# - Jumping Jacks: 1 Minute
#
# WORKOUT - 4 Rounds:
# - Sumo Squats To Calf Raise: 20
# - Standing Oblique Twists: 30
# - Box Jumps: 20
#
# Weeks 5-6:
#
# DAY 1:
#
# WORKOUT - TABATA:
# - Burpees: 30 Seconds
# - Mountain Climbers: 45 Seconds
# - Push up To Down Dog: 45 Seconds
#
# WORKOUT - 7 Minute AMRAP:
# - Side Plank: 30 Seconds
# - Push Ups: 10
# - Side Lunge: 10 Each Side
# - V-Ups: 10
# - Toe Touch Planks: 10
#
# DAY 2:
#
# WORKOUT - EMOM 8 Rounds:
# - Push Ups: 12
# - Squat Jumps: 15
# - Glute Bridges: 20
# - High Knees: 25
#
# FINISHER - 3 Rounds:
# - Mountain Climbers: 1 Minute
# - Wall Sit Alternating Calf Raise: 1 Minute
# - Step Ups: 1 Minute
#
# DAY 3:
#
# WORKOUT - 20 Minute AMRAP:
# - Speed Skaters: 20 Seconds
# - Right Side Plank: 30 Seconds
# - Reverse Lunge To High Knees: 10 Each Side
# - Left Side Plank: 30 Seconds
# - Squats: 15
#
# WORKOUT - 3 Rounds:
# - Burpees: 15
# - Standing Adduction: 10 Each Side
# - Crossed Leg Reverse Crunch: 10 Each Side
#
# DAY 4:
#
# WORKOUT - 10 Minute AMRAP:
# - Push Ups: 10
# - Plank to Toe Touch: 20
# - Butt Kickers: 30
# - Jump Squats: 30
#
# WORKOUT - 8 Minute AMRAP:
# - Flutter Kicks: 10
# - Burpee To High Knee Tuck: 20
# - High Knees: 30
# - Speed Skaters: 30
#
# WORKOUT - 10 Minute AMRAP:
# - Push Up To Alternating Toe Touch: 10
# - Plank: 20 seconds
# - Mountain Climbers: 30 Seconds
# - Sit Up To Glute Bridge: 30
#
# DAY 5:
#
# WORKOUT - TABATA:
# - Pulsing Squats: 30 Seconds
# - Side Planks: 45 Seconds
# - Russian Twists: 45 Seconds
#
# WORKOUT - 5 Rounds:
# - Tricep Dips: 20
# - High Knees: 20
# - Squats: 10
# - Push Ups: 10
# - Dead Bugs: 10

# %%
import tiktoken

# %%
def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
num_tokens_from_string(test, 'cl100k_base')
# Out:
# 8524

# %%
'AIzaSyCapu0rOU5yJa_W3tK9RJf2p7u8wmDiWNU'

# %%
import google.generativeai as genai
import os

genai.configure(api_key='AIzaSyCapu0rOU5yJa_W3tK9RJf2p7u8wmDiWNU')

model = genai.GenerativeModel(model_name='gemini-1.5-flash')
response = model.generate_content('Please summarise this document: ...')

print(response.text)
# Out:
# Please provide me with the document you would like me to summarise. I need the text of the document to be able to understand its content and provide a concise summary.
